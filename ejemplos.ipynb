# %%
# %run main.py \
    --new_data \
    --dir_data Data \
    --dir_sufix_out test \
    --do_evaluation \
    --do_metrics \
    --do_cross_val \
    --show_plot_detail \
    --reps 1 \
    --Nus 0.05 0.1 \
    --num_train 100 \
    --num_val 66 \
    --num_test 166 \
    --anom_frac 0.10 \
    --data_shape spherical \
    --method svdd
# Out:
# Data generated with ntrain = 100 , nval = 66 , ntest = 166 , anom_frac = 0.1 , reps = [1]
# Data_Prim_test/solucion_svdd_spherical_datak1_k1_100_66_166_anom0.1_rep1_nu0.05_sigma-1.0.pkl
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-11-26
# Primal - Nº Datos: 100  - Dim: 2  - Nu: 0.05  - C: 0.2
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 25.6.0 25G83)
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Non-default parameters:
# TimeLimit  3600
#
# Optimize a model with 0 rows, 103 columns and 0 nonzeros
# Model fingerprint: 0x652b0b85
# Model has 100 quadratic constraints
# Coefficient statistics:
#   Matrix range     [0e+00, 0e+00]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [5e-03, 7e+00]
#   Objective range  [2e-01, 1e+00]
#   Bounds range     [0e+00, 0e+00]
# ...

# %%
# %run main.py \
    --new_data \
    --dir_data Data \
    --dir_sufix_out test \
    --do_evaluation \
    --do_metrics \
    --do_cross_val \
    --show_plot_detail \
    --reps 1 \
    --Nus 0.05 0.1 \
    --num_train 100 \
    --num_val 66 \
    --num_test 166 \
    --anom_frac 0.10 \
    --data_shape spherical \
    --method clustersvdd \
    --data_k 2 \
    --k 2
# Out:
# Data generated with ntrain = 100 , nval = 66 , ntest = 166 , anom_frac = 0.1 , reps = [1]
# Data_Prim_test/solucion_clustersvdd_spherical_datak2_k2_100_66_166_anom0.1_rep1_nu0.05_sigma-1.0.pkl
# Primal - Nº Datos: 55  - Dim: 2  - Nu: 0.05  - C: 0.36363636363636365
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 25.6.0 25G83)
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Non-default parameters:
# TimeLimit  3600
#
# Optimize a model with 0 rows, 58 columns and 0 nonzeros
# Model fingerprint: 0xe595276e
# Model has 55 quadratic constraints
# Coefficient statistics:
#   Matrix range     [0e+00, 0e+00]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [3e-01, 7e+00]
#   Objective range  [4e-01, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [0e+00, 0e+00]
#   QRHS range       [1e+00, 2e+01]
# ...

# %%
# %run main.py \
    --new_data \
    --dir_data Data \
    --dir_sufix_out test \
    --do_evaluation \
    --do_metrics \
    --do_cross_val \
    --show_plot_detail \
    --reps 1 \
    --Nus 0.05 0.1 \
    --num_train 100 \
    --num_val 66 \
    --num_test 166 \
    --anom_frac 0.10 \
    --data_shape spherical \
    --method clustersvdd \
    --data_k 2 \
    --k 2 \
    --use_density
# Out:
# Data generated with ntrain = 100 , nval = 66 , ntest = 166 , anom_frac = 0.1 , reps = [1]
# Data_Prim_test/solucion_clustersvdd_dw_spherical_datak2_k2_100_66_166_anom0.1_rep1_nu0.05_sigma-1.0.pkl
# Primal - Nº Datos: 55  - Dim: 2  - Nu: 0.05  - C: 0.36363636363636365
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 25.6.0 25G83)
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Non-default parameters:
# TimeLimit  3600
#
# Optimize a model with 0 rows, 58 columns and 0 nonzeros
# Model fingerprint: 0x235f8e27
# Model has 55 quadratic constraints
# Coefficient statistics:
#   Matrix range     [0e+00, 0e+00]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [3e-01, 7e+00]
#   Objective range  [7e-02, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [0e+00, 0e+00]
#   QRHS range       [1e+00, 2e+01]
# ...
